# %%
from main import *

# %%
plot_confusion_region()
# Out:
# Thresholds: 100%|██████████| 100/100 [00:08<00:00, 11.27it/s]

# %%
start_search()
# Out:
# LPM Search:   0%|          | 0/10 [00:00<?, ?it/s]
# Theta Search Space: [0, 1.5707963267948966]
# LPM Search:  10%|█         | 1/10 [00:00<00:02,  4.35it/s]
# Theta Search Space: [0, 0.7853981633974483]
# LPM Search:  20%|██        | 2/10 [00:00<00:01,  4.46it/s]
# Theta Search Space: [0, 0.39269908169872414]
# LPM Search:  30%|███       | 3/10 [00:00<00:01,  4.44it/s]
# Theta Search Space: [0, 0.19634954084936207]
# LPM Search:  40%|████      | 4/10 [00:00<00:01,  4.47it/s]
# Theta Search Space: [0.04908738521234052, 0.14726215563702155]
# LPM Search:  50%|█████     | 5/10 [00:01<00:01,  4.47it/s]
# Theta Search Space: [0.07363107781851078, 0.1227184630308513]
# LPM Search:  60%|██████    | 6/10 [00:01<00:00,  4.45it/s]
# Theta Search Space: [0.0859029241215959, 0.11044661672776615]
# LPM Search:  70%|███████   | 7/10 [00:01<00:00,  4.46it/s]
# Theta Search Space: [0.09203884727313846, 0.10431069357622359]
# LPM Search:  80%|████████  | 8/10 [00:01<00:00,  4.48it/s]
# ...
